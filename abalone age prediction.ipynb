# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Lenovo'

# %%
os.chdir('C:/Users/Lenovo/Desktop/data sets')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Lenovo\\Desktop\\data sets'

# %%
import numpy as np
import pandas as pd
from sklearn import preprocessing
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data1=pd.read_csv('abalone.csv')

# %%
data1
# Out:
#      Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# 5      I   0.425     0.300   0.095        0.3515          0.1410
# 6      F   0.530     0.415   0.150        0.7775          0.2370
# 7      F   0.545     0.425   0.125        0.7680          0.2940
# 8      M   0.475     0.370   0.125        0.5095          0.2165
# 9      F   0.550     0.440   0.150        0.8945          0.3145
# 10     F   0.525     0.380   0.140        0.6065          0.1940
# 11     M   0.430     0.350   0.110        0.4060          0.1675
# 12     M   0.490     0.380   0.135        0.5415          0.2175
# ...

# %%
# list a count of missing values in dataset
data1.apply(lambda x:sum(x.isnull()),axis=0)
# Out:
# Sex                      0
# Length                   0
# Diameter                 0
# Height                   0
# Whole_weight             0
# Shucked_weight           0
# Viscera_weight           0
# Shell_weight             0
# Class_number_of_rings    0
# dtype: int64

# %%
data1.Sex.value_counts()
# Out:
# M    1528
# I    1342
# F    1307
# Name: Sex, dtype: int64

# %%
data1['Sex'].replace(['M','I','F'],[1,0,2],inplace=True)

# %%
data1
# Out:
#       Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# 0       1   0.455     0.365   0.095        0.5140          0.2245
# 1       1   0.350     0.265   0.090        0.2255          0.0995
# 2       2   0.530     0.420   0.135        0.6770          0.2565
# 3       1   0.440     0.365   0.125        0.5160          0.2155
# 4       0   0.330     0.255   0.080        0.2050          0.0895
# 5       0   0.425     0.300   0.095        0.3515          0.1410
# 6       2   0.530     0.415   0.150        0.7775          0.2370
# 7       2   0.545     0.425   0.125        0.7680          0.2940
# 8       1   0.475     0.370   0.125        0.5095          0.2165
# 9       2   0.550     0.440   0.150        0.8945          0.3145
# 10      2   0.525     0.380   0.140        0.6065          0.1940
# 11      1   0.430     0.350   0.110        0.4060          0.1675
# 12      1   0.490     0.380   0.135        0.5415          0.2175
# ...

# %%
X=data1[['Sex','Length','Diameter','Height','Whole_weight','Shucked_weight','Viscera_weight','Shell_weight']]
y=data1['Class_number_of_rings']

# %%
X
# Out:
#       Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# 0       1   0.455     0.365   0.095        0.5140          0.2245
# 1       1   0.350     0.265   0.090        0.2255          0.0995
# 2       2   0.530     0.420   0.135        0.6770          0.2565
# 3       1   0.440     0.365   0.125        0.5160          0.2155
# 4       0   0.330     0.255   0.080        0.2050          0.0895
# 5       0   0.425     0.300   0.095        0.3515          0.1410
# 6       2   0.530     0.415   0.150        0.7775          0.2370
# 7       2   0.545     0.425   0.125        0.7680          0.2940
# 8       1   0.475     0.370   0.125        0.5095          0.2165
# 9       2   0.550     0.440   0.150        0.8945          0.3145
# 10      2   0.525     0.380   0.140        0.6065          0.1940
# 11      1   0.430     0.350   0.110        0.4060          0.1675
# 12      1   0.490     0.380   0.135        0.5415          0.2175
# ...

# %%
y
# Out:
# 0       15
# 1        7
# 2        9
# 3       10
# 4        7
# 5        8
# 6       20
# 7       16
# 8        9
# 9       19
# 10      14
# 11      10
# 12      11
# 13      10
# 14      10
# 15      12
# 16       7
# 17      10
# 18       7
# 19       9
# 20      11
# 21      10
# 22      12
# 23       9
# 24      10
# 25      11
# 26      11
# 27      12
# 28      15
# 29      11
#         ..
# 4147    11
# 4148    11
# 4149     6
# 4150     7
# 4151     6
# 4152     7
# 4153     8
# 4154     6
# 4155     6
# 4156     8
# 4157     8
# 4158     8
# 4159     9
# 4160    11
# 4161    11
# 4162     8
# 4163     7
# 4164     7
# 4165     7
# 4166    10
# 4167     9
# 4168     8
# 4169    10
# 4170    10
# 4171     8
# 4172    11
# 4173    10
# 4174     9
# 4175    10
# 4176    12
# Name: Class_number_of_rings, Length: 4177, dtype: int64

# %%
import statsmodels.api as sm

# %%
model1=sm.OLS(y,X).fit()
predictions=model1.predict(X)
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               OLS Regression Results
# ...
# Dep. Variable:     Class_number_of_rings   R-squared:                       0.954
# Model:                               OLS   Adj. R-squared:                  0.954
# Method:                    Least Squares   F-statistic:                 1.083e+04
# Date:                   Wed, 29 May 2019   Prob (F-statistic):               0.00
# Time:                           10:30:07   Log-Likelihood:                -9290.7
# No. Observations:                   4177   AIC:                         1.860e+04
# Df Residuals:                       4169   BIC:                         1.865e+04
# Df Model:                              8
# Covariance Type:               nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %%
# apply normalization
minmax=preprocessing.MinMaxScaler(feature_range=(0,1))
minmax.fit(X).transform(X)
# Out:
# C:\Users\Lenovo\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:323: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)
# array([[0.5       , 0.51351351, 0.5210084 , ..., 0.15030262, 0.1323239 ,
#         0.14798206],
#        [0.5       , 0.37162162, 0.35294118, ..., 0.06624075, 0.06319947,
#         0.06826109],
#        [1.        , 0.61486486, 0.61344538, ..., 0.17182246, 0.18564845,
#         0.2077728 ],
#        ...,
#        [0.5       , 0.70945946, 0.70588235, ..., 0.3527236 , 0.37788018,
#         0.30543099],
#        [1.        , 0.74324324, 0.72268908, ..., 0.35642233, 0.34298881,
#         0.29347285],
#        [0.5       , 0.85810811, 0.84033613, ..., 0.63517149, 0.49506254,
#         0.49177877]])

# %%
#splitting the data
from sklearn import model_selection,neighbors
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=1)

# %%
X_train
# Out:
#       Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# 666     1   0.455     0.350   0.120        0.4835          0.1815
# 2813    0   0.255     0.195   0.055        0.0725          0.0285
# 1862    0   0.520     0.410   0.110        0.5185          0.2165
# 3684    0   0.620     0.470   0.155        0.9660          0.4470
# 551     0   0.615     0.490   0.155        0.9885          0.4145
# 3586    0   0.630     0.465   0.150        1.0315          0.4265
# 313     2   0.620     0.470   0.200        1.2255          0.3810
# 3180    2   0.370     0.295   0.100        0.2685          0.1165
# 1089    0   0.450     0.330   0.105        0.3715          0.1865
# 382     1   0.485     0.400   0.135        0.6630          0.3130
# 75      2   0.600     0.475   0.150        1.0075          0.4425
# 2589    1   0.575     0.450   0.155        0.9480          0.4290
# 3057    1   0.615     0.490   0.170        1.1450          0.4915
# ...

# %%
X_test
# Out:
#       Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# 17      2   0.440     0.340   0.100        0.4510          0.1880
# 1131    1   0.565     0.435   0.150        0.9900          0.5795
# 299     1   0.370     0.280   0.105        0.2340          0.0905
# 1338    1   0.580     0.455   0.135        0.7955          0.4050
# 2383    2   0.525     0.390   0.135        0.6005          0.2265
# 2039    0   0.285     0.215   0.070        0.1075          0.0510
# 3127    2   0.620     0.485   0.155        1.1945          0.5105
# 791     2   0.485     0.375   0.135        0.5560          0.1925
# 3599    1   0.735     0.555   0.220        2.3330          1.2395
# 1566    0   0.465     0.370   0.120        0.4365          0.1880
# 3281    1   0.550     0.450   0.170        0.8100          0.3170
# 3009    0   0.255     0.185   0.065        0.0740          0.0305
# 1004    2   0.605     0.490   0.150        1.1345          0.5265
# ...

# %%
y_train
# Out:
# 666     11
# 2813     4
# 1862     8
# 3684    11
# 551     13
# 3586    11
# 313     23
# 3180     7
# 1089     7
# 382     10
# 75      15
# 2589     7
# 3057    13
# 1034     9
# 2684     9
# 2830     9
# 4083    10
# 3515    12
# 2437     9
# 473     11
# 188     11
# 4089     9
# 329      8
# 909      7
# 89      12
# 3767    10
# 2983     8
# 367     10
# 1903    10
# 297      4
#         ..
# 542     15
# 4074     8
# 431     20
# 728     13
# 2561     6
# 1337    10
# 3606     7
# 2877     9
# 1031     9
# 1110     8
# 1888    11
# 3550     8
# 1527    12
# 753     13
# 3049     9
# 2628     5
# 562     11
# 3562     8
# 252     12
# 2516    10
# 2962     9
# 1202    12
# 3462    10
# 2797    11
# 144     10
# 2895    10
# 2763    10
# 905      5
# 3980     7
# 235      9
# Name: Class_number_of_rings, Length: 3341, dtype: int64

# %%
y_test
# Out:
# 17      10
# 1131     8
# 299      9
# 1338    10
# 2383    16
# 2039     6
# 3127     9
# 791     10
# 3599    12
# 1566     9
# 3281    11
# 3009     4
# 1004     9
# 4053    10
# 1070     6
# 1167     8
# 3167    15
# 2618    13
# 2966    10
# 2939    10
# 610     12
# 1708    14
# 913      6
# 280     15
# 3450     7
# 2698     9
# 2088    12
# 3312    17
# 1962    10
# 880     11
#         ..
# 994      8
# 1398    11
# 3948    12
# 1162     9
# 2481     8
# 1448     9
# 3348    13
# 1535     6
# 3735     9
# 3720     7
# 3331    11
# 3257     9
# 3178     8
# 1329     8
# 255     15
# 3797    13
# 1232     7
# 3060    11
# 2706    11
# 2448     7
# 107     10
# 2842     9
# 3017     8
# 2553     7
# 1519    10
# 1787     8
# 3075    11
# 2766     8
# 1410    10
# 2529     8
# Name: Class_number_of_rings, Length: 836, dtype: int64

# %%
y_train=y_train.astype('int')

# %%
y_train
# Out:
# 666     11
# 2813     4
# 1862     8
# 3684    11
# 551     13
# 3586    11
# 313     23
# 3180     7
# 1089     7
# 382     10
# 75      15
# 2589     7
# 3057    13
# 1034     9
# 2684     9
# 2830     9
# 4083    10
# 3515    12
# 2437     9
# 473     11
# 188     11
# 4089     9
# 329      8
# 909      7
# 89      12
# 3767    10
# 2983     8
# 367     10
# 1903    10
# 297      4
#         ..
# 542     15
# 4074     8
# 431     20
# 728     13
# 2561     6
# 1337    10
# 3606     7
# 2877     9
# 1031     9
# 1110     8
# 1888    11
# 3550     8
# 1527    12
# 753     13
# 3049     9
# 2628     5
# 562     11
# 3562     8
# 252     12
# 2516    10
# 2962     9
# 1202    12
# 3462    10
# 2797    11
# 144     10
# 2895    10
# 2763    10
# 905      5
# 3980     7
# 235      9
# Name: Class_number_of_rings, Length: 3341, dtype: int32

# %%
y_test=y_test.astype('int')

# %%
y_test
# Out:
# 17      10
# 1131     8
# 299      9
# 1338    10
# 2383    16
# 2039     6
# 3127     9
# 791     10
# 3599    12
# 1566     9
# 3281    11
# 3009     4
# 1004     9
# 4053    10
# 1070     6
# 1167     8
# 3167    15
# 2618    13
# 2966    10
# 2939    10
# 610     12
# 1708    14
# 913      6
# 280     15
# 3450     7
# 2698     9
# 2088    12
# 3312    17
# 1962    10
# 880     11
#         ..
# 994      8
# 1398    11
# 3948    12
# 1162     9
# 2481     8
# 1448     9
# 3348    13
# 1535     6
# 3735     9
# 3720     7
# 3331    11
# 3257     9
# 3178     8
# 1329     8
# 255     15
# 3797    13
# 1232     7
# 3060    11
# 2706    11
# 2448     7
# 107     10
# 2842     9
# 3017     8
# 2553     7
# 1519    10
# 1787     8
# 3075    11
# 2766     8
# 1410    10
# 2529     8
# Name: Class_number_of_rings, Length: 836, dtype: int32

# %%
from sklearn import linear_model as lm
model=lm.LinearRegression()
results=model.fit(X_train,y_train)

# %%
model
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
results
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
accuracy=model.score(X_train,y_train)
print('Accuracy of the model:',accuracy)
# Out:
# Accuracy of the model: 0.5391534282793788

# %%
#print coefficients
print('intercept:',model.intercept_)
print('slope:',model.coef_)
# Out:
# intercept: 3.097774835554717
# slope: [  0.34594905  -1.37901601  12.76280954   9.81511054   8.8200456
#  -19.84156708  -9.65433828   9.12464446]

# %%
model=lm.LinearRegression()
results=model.fit(X_test,y_test)

# %%
model
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
results
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
accuracy=model.score(X_test,y_test)
print('Accuracy of the model:',accuracy)
# Out:
# Accuracy of the model: 0.5163634914175881
